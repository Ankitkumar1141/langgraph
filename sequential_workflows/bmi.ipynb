# %% [markdown]
# #### BMI computation using sequential workflow

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BMIState(TypedDict):
    weight: float
    height: float
    bmi: float
    category: str

# %%
def calculate_bmi(state: BMIState) ->BMIState:
    weight = state["weight"]
    height = state["height"]

    bmi = weight / (height ** 2)
    state["bmi"] = round(bmi,2)
    return state

# %%
def label_bmi(state: BMIState) -> BMIState:
    bmi = state[bmi]
    if bmi < 18.5:
        state["category"] = "Underweight"
    elif 18.5 <= bmi <24.9:
        state["category"] = "Normal weight"
    elif 25 <= bmi <29.9:
        state["category"] = "Overweight"
    else:
        state["category"] = "Obese"
    return state

# %%
graph = StateGraph(BMIState)

## add notes to your graph
graph.add_note("calculate_bmi",calculate_bmi)
graph.add_note("label_bmi",label_bmi)

# %%
### add edges to your graph
graph.add_edge(START,"calculate_bmi")
graph.add_edge("calculate_bmi","label_bmi")
graph.add_edge("label_bmi",END)

# %%
workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 workflow = graph.compile()
#
# File d:\langraph\langraph_venv\Lib\site-packages\langgraph\graph\state.py:1261, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name, transformers)
#    1258 interrupt_after = interrupt_after or []
#    1260 # validate the graph
# -> 1261 self.validate(
#    1262     interrupt=(
#    1263         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1264         if interrupt_after != "*"
#    1265         else []
#    1266     )
#    1267 )
#    1269 # prepare output channels
#    1270 output_channels = (
#    1271     "__root__"
#    1272     if len(self.schemas[self.output_schema]) == 1
#    (...)   1278     ]
#    1279 )
#
# File d:\langraph\langraph_venv\Lib\site-packages\langgraph\graph\state.py:1140, in StateGraph.validate(self, interrupt)
#    1138 for source in all_sources:
#    1139     if source not in self.nodes and source != START:
# -> 1140         raise ValueError(f"Found edge starting at unknown node '{source}'")
#    1142 if START not in all_sources:
#    1143     raise ValueError(
#    1144         "Graph must have an entrypoint: add at least one edge from START to another node"
#    1145     )
#
# ValueError: Found edge starting at unknown node 'categorize_bmi'
